# %% [markdown]
# # Supervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of supervised learning model evaluation.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Regression Model Evaluation

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)

# %%
"""
CRIM - per capita crime rate by town
ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
INDUS - proportion of non-retail business acres per town.
CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
NOX - nitric oxides concentration (parts per 10 million)
RM - average number of rooms per dwelling
AGE - proportion of owner-occupied units built prior to 1940
DIS - weighted distances to five Boston employment centres
RAD - index of accessibility to radial highways
TAX - full-value property-tax rate per $10,000
PTRATIO - pupil-teacher ratio by town
B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
LSTAT - % lower status of the population
MEDV - Median value of owner-occupied homes in $1000's"""
# Out:
# "\nCRIM - per capita crime rate by town\nZN - proportion of residential land zoned for lots over 25,000 sq.ft.\nINDUS - proportion of non-retail business acres per town.\nCHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)\nNOX - nitric oxides concentration (parts per 10 million)\nRM - average number of rooms per dwelling\nAGE - proportion of owner-occupied units built prior to 1940\nDIS - weighted distances to five Boston employment centres\nRAD - index of accessibility to radial highways\nTAX - full-value property-tax rate per $10,000\nPTRATIO - pupil-teacher ratio by town\nB - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town\nLSTAT - % lower status of the population\nMEDV - Median value of owner-occupied homes in $1000's"

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ## 1. Split this data set into training (80%) and testing (20%) sets.
#
# The `MEDV` field represents the median value of owner-occupied homes (in $1000's) and is the target variable that we will want to predict.

# %%
# Your code here :
from sklearn.model_selection import train_test_split
x=data.drop('MEDV',axis=1)
y=data['MEDV']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## 2. Train a `LinearRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
# Your code here :
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#make predictions
pred=model.predict(x_train)
pred2=model.predict(x_test)
print(pred)
print(pred2)
# Out:
# [10.96952405 19.41196567 23.06419602 12.1470648  18.3738116  25.24677946
#  20.77024774 23.90932632  7.81713319 19.60988098 21.8202963  27.59615864
#  32.67986504 15.12308446 35.3964561  12.99688651 20.728181   28.30223542
#  15.61724836 24.45143096  4.61794591 23.76681932 25.56178249 22.98928526
#  24.5213025  34.06407919 19.71166707 39.11233072 14.62515846 24.81139885
#  18.02332883 20.85836445  9.57577261 20.87246835 22.28583096 31.79327155
#  31.04748307 15.70611763 17.01382935 28.23332703 24.27661276 16.88670215
#   6.90720745 26.75808901 22.586493   17.53664716 13.77197016 41.04840929
#  16.44690754 18.23531669 25.37038646 23.64581399 22.05322581 20.83620499
#  16.93508273 22.797579   29.13333934  7.69310515 24.60571452 17.2358028
#  21.10846551 25.15150324 27.33394823 21.30494963 41.5811902  19.19666651
#  15.37955448 19.33545877 17.04687638 22.96801532 23.11094953 33.6977586
#  22.77436405 20.28968381 25.35517813 31.02479125 33.05103792 28.44712333
# ...

# %% [markdown]
# ## 3. Calculate and print R-squared for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import r2_score
R_sq_train=r2_score(y_train,pred)
R_sq_test=r2_score(y_test,pred2)
print(f"R-squared score for training: {R_sq_train}")
print(f"R-squared score for testing: {R_sq_test}")
# Out:
# R-squared score for training: 0.7508856358979672
# R-squared score for testing: 0.6687594935356289

# %% [markdown]
# ## 4. Calculate and print mean squared error for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import mean_squared_error
mse_train=mean_squared_error(y_train,pred)
mse_test=mean_squared_error(y_test,pred2)
print(f"mean squared error for training: {mse_train}")
print(f"mean squared error for testing: {mse_train}")
# Out:
# mean squared error for training: 21.641412753226316
# mean squared error for testing: 21.641412753226316

# %% [markdown]
# ## 5. Calculate and print mean absolute error for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_train,pred)
mae2=mean_absolute_error(y_test,pred2)
print(f"mean absolute error for training: {mae}")
print(f"mean absolute error for testing: {mae2}")
# Out:
# mean absolute error for training: 3.314771626783233
# mean absolute error for testing: 3.189091965887874

# %% [markdown]
# ## Classification Model Evaluation

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
print(data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
column_names = data.feature_names

# %%
df = pd.DataFrame(data['data'],columns=column_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
target = pd.DataFrame(data.target)
target
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ## 6. Split this data set into training (80%) and testing (20%) sets.
#
# The `class` field represents the type of flower and is the target variable that we will want to predict.

# %%
# Your code here :

x_train,x_test,y_train,y_test=train_test_split(df,target,test_size=0.2,random_state=42)

# %% [markdown]
# ## 7. Train a `LogisticRegression` model on this data set and generate predictions on both the training and the testing set.

# %%
# Your code here :
from sklearn.linear_model import LogisticRegression
model2=LogisticRegression()
model2.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#make predictions
pre=model2.predict(x_train)
pre2=model2.predict(x_test)
print(pre)
print(pre2)
# Out:
# [0 0 1 0 0 2 1 0 0 0 2 1 1 0 0 1 2 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1
#  2 0 1 2 0 2 2 1 1 2 1 0 1 2 0 0 1 2 0 2 0 0 2 1 2 2 2 2 1 0 0 2 2 0 0 0 1
#  2 0 2 2 0 1 1 2 1 2 0 2 1 2 1 1 1 0 1 1 0 1 2 2 0 1 2 2 0 2 0 1 2 2 1 2 1
#  1 2 2 0 1 2 0 1 2]
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %% [markdown]
# ## 8. Calculate and print the accuracy score for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import accuracy_score
acct=accuracy_score(y_train,pre)
accs=accuracy_score(y_test,pre2)
print(f"accuracy_scorer for training: {acct}")
print(f"accuracy_score error for testing: {accs}")
# Out:
# accuracy_scorer for training: 0.975
# accuracy_score error for testing: 1.0

# %% [markdown]
# ## 9. Calculate and print the balanced accuracy score for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import balanced_accuracy_score
bt=balanced_accuracy_score(y_train,pre)
bs=balanced_accuracy_score(y_test,pre2)
print(f"balanced accuracy_scorer for training: {bt}")
print(f"balanced accuracy_score  for testing: {bs}")
# Out:
# balanced accuracy_scorer for training: 0.975609756097561
# balanced accuracy_score  for testing: 1.0

# %% [markdown]
# ## 10. Calculate and print the precision score for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import precision_score
pct=precision_score(y_train,pre,average=None)
pcs=precision_score(y_test,pre2,average=None)
print(f"precision_scorefor training: {pct}")
print(f"precision_score  for testing: {pcs}")
# Out:
# precision_scorefor training: [1.         1.         0.92857143]
# precision_score  for testing: [1. 1. 1.]

# %% [markdown]
# ## 11. Calculate and print the recall score for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import recall_score
r1=recall_score(y_train,pre,average=None)
r2=recall_score(y_test,pre2,average=None)
print(f"recall_score for training: {r1}")
print(f"recall_score  for testing: {r2}")
# Out:
# recall_score for training: [1.         0.92682927 1.        ]
# recall_score  for testing: [1. 1. 1.]

# %% [markdown]
# ## 12. Calculate and print the F1 score for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import f1_score
f1=f1_score(y_train,pre,average=None)
f2=f1_score(y_test,pre2,average=None)
print(f"f1_score for training:\n {f1}")
print(f"f1_score  for testing:\n {f2}")
# Out:
# f1_score for training:
#  [1.         0.96202532 0.96296296]
# f1_score  for testing:
#  [1. 1. 1.]

# %% [markdown]
# ## 13. Generate confusion matrices for both the training and the testing set.

# %%
# Your code here :
from sklearn.metrics import confusion_matrix
c1=confusion_matrix(y_train,pre,)
c2=confusion_matrix(y_test,pre2,)
print(f"confusion_matrix for training:\n {c1}")
print(f"confusion_matrix  for testing:\n {c2}")
# Out:
# confusion_matrix for training:
#  [[40  0  0]
#  [ 0 38  3]
#  [ 0  0 39]]
# confusion_matrix  for testing:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %% [markdown]
# ## Bonus: For each of the data sets in this lab, try training with some of the other models you have learned about, recalculate the evaluation metrics, and compare to determine which models perform best on each data set.

# %%
# Have fun here !
